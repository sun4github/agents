# %%
from dotenv import load_dotenv
from pypdf import PdfReader
import gradio as gr
from openai import OpenAI


load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("../me/Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# suneel.kanuri@gmail.com
# www.linkedin.com/in/suneel-
# kanuri-2253667970 (LinkedIn)
# www.suneelkanuri.com (Personal)
# github.com/sun4github (Other)
# Top Skills
# OCI
# Architecture
# Speech Recognition
# Languages
# English (Native or Bilingual)
# Telugu (Native or Bilingual)
# Hindi (Professional Working)
# Tamil (Limited Working)
# Certifications
# Oracle Cloud Infrastructure 2025
# Multicloud Architect Professional
# Dale Carnegie Course in Effective
# Communication and Human
# Relations
# Microsoft Certified: Azure AI
# Fundamentals
# Oracle Cloud Infrastructure 2025 AI
# Foundations Associate
# Suneel Kanuri
# Cloud Solution Architect | Azure | High-Performance Applications
# Fort Mill, South Carolina, United States
# Summary
# Delivery focused and highly motivated technology architect with
# hands-on experience in system architecture and cloud computing.
# Currently working as a lead software engineer / architect for
# Enterprise Knowledge Base (EKB) team, assisting the development
# team and other associated teams deliver Fast, Secure, Reliable and
# Easy to maintain applications
# Skill set:  Application / System Architecture, .NET Core, Azure,
# AWS, RDF, SPARQL, Cosmos DB, C#, Kubernetes, REST API,
# JavaScript, Service Bus, App Insights
# Experience
# Self
# Senior Application Architect
# April 2023 - Present (2 years 11 months)
# ● Facilitate integration of AI and ML to web apps, transforming them to truly
# intelligent apps that drive impactful business outcomes, utilizing RAG, Genie
# Spaces and Databricks
# ● Establish and mold the Architecture and methodologies
# ● Conduct application quality and performance evaluations
# ● Direct and navigate vendor discussions regarding architectural needs for
# new application development.
# ● Assess technologies and products for varied requirements in the org and
# develop proof-of-concept projects to expedite application development
# initiatives.
# ● Assist in product development by spinning up starter and demo projects with
# all involved technologies, to be adopted for further development by the Dev
# team
# ● Support product development teams in optimizing source code, debugging
# issues and in solving challenges encountered.
#   Page 1 of 6
# GlobalLogic
# Cloud Solution Architect
# November 2020 - April 2023 (2 years 6 months)
# Charlotte, North Carolina, United States
# ● Architected Highly-Available solutions in Azure primarily using Azure
# Functions, Azure Kubernetes Service, App Services, Event Grid, Event Hub
# ( Kafka ), Azure API Management, Azure Traffic Manager and Service Bus
# ● Designed & Implemented an efficient search mechanism with facets,
# across our datastores (Cosmos DB, SQL Server and GraphQL data from
# TopQuadrant ) using Azure Cognitive Services and Azure Redis Cache
# ● Automated infrastructure components using ARM Templates, Terraform and
# Azure CLI along with Python scripts.
# ● Managed and Monitored Applications and API’s using Application Insights,
# alerts, Azure Monitor and Log Analytics.
# ● Managed Identities using OAuth2 and Azure Active Directory
# ● Secured Applications using Azure KeyVault, NSG (Firewalls), Access
# restrictions, Service Endpoints, Azure Application Gateway and VNet Peering
# ● Assisted the higher management transform the strategic initiatives to desired
# outcomes and realize business value by driving delivery teams focused
# towards achieving those outcomes.
# ● Guided the team by providing necessary technical guidance, leadership and
# architecture in building scalable cloud native microservices on Azure
# ● Worked with DevOps teams in setting up Azure Pipelines for efficient and
# continuous delivery (CI/CD) of our products
# ● Performed non-functional requirement analysis namely response time,
# security, scalability and stability
# ● Explored new age technologies such as RDF (Graph Data), SPARQL and
# built POC products to kick start the team in building innovative solutions that
# meet the client's diverse business needs
# AGDATA, LP
# 1 year 9 months
# Technical Lead
# September 2019 - November 2020 (1 year 3 months)
# Charlotte, North Carolina Area
# ● Lead the team by providing necessary technical guidance, leadership and
# removing blockers
# ● Organized scrums & worked as a Scrum master, to ensure the success
# of daily standups, backlog grooming and sprint planning with a eye towards
# improving the sprint capacity & team confidence
#   Page 2 of 6
# ● Worked closely with the Development and QA teams on architecture and
# technologies.
# ● Performed root cause analysis for service interruption recovery and
# established preventative measures for future.
# ● Worked on creating Azure Pipelines, Releases and Test Plans to implement
# CI/CD for the products managed by my team. Coached our engineering teams
# on CI/CD and Azure.
# ● Created and deployed Terraform Scripts, ARM templates and Powershell
# scripts for resource management in Azure
# ● Worked on defining API contracts, and implemented Microservices for our
# internal and external clients while also enforcing the best compliance with
# REST standards
# ● Refactored & Assisted other team members in upgrading older .NET projects
# to a distributed microservices architecture for better scaling and to utilize the
# latest versions of .NET Core while also introducing design patterns and Unit
# tests.
# Senior Software Engineer / Architect
# March 2019 - September 2019 (7 months)
# Charlotte, North Carolina Area
# ● Developed software, Microservices and Windows services using C# ( .NET
# Core ), ASP.NET Core and SQL Server
# ● Containerized applications using Docker Images and orchestrated scaling
# using Kubernetes ( Google Kubernetes Engine and Azure Kubernetes Service)
# ● Utilized best architectural practices such as Loose-Coupling ( using Service
# Bus ) and SOLID principles.
# ● Designed multi-node microservice applications using Azure Service Fabric,
# and Service Bus ( Queue ) with CQRS architecture
# ● Utilized Azure based cloud services such as ServiceBus, Blob Containers, ,
# Resource Groups, Namespaces and Application Insights
# ● Performed Application migrations to Azure Devops,  Azure Repos ( from
# Bitbucket and Github ), and setup Azure Pipelines for Releases and Builds
# ● Migrated nuget packages from our local Nuget server to Azure Artifacts, and
# setup multiple feeds for different teams
# ● Developed Infrastructure as code (IaaS) scripts for configuration
# management using software like Terraform, ARM templates and Powershell
# ● Reviewed & implemented test plans, to ensure the best Unit test coverage
# ● Reviewed & Refactored solutions for scalability, and maximum availability
# ● Designed and utilized Azure Cosmos DB tables to speed up reporting on
# MDM data for Growers and Retailers
#   Page 3 of 6
# ● Assisted in performing phone & on-site interviews for technical & product
# management resources
# ● Encouraged & participated in implementing TDD practices ( red/green
# strategies ) within the team
# Blue Streak Technologies
# Lead Software Engineer
# May 2010 - March 2019 (8 years 11 months)
# Baton Rouge, Louisiana Area
# * Technical Lead over SANDY INTEGRATED RECOVERY OPERATIONS
# AND MANAGEMENT SYSTEM ("SIROMS") team that provides Workflow
# solutions for RREM Program,LMI, LRRP among others using OpenText,
# C#.NET, RESTful API, SOAP, Javascript, Node.js, JQuery, JSON, iTextSharp
# and Cloud based document management.
# * Architected and developed Matter & Event Management Solution for Legal
# Clients using AWS Lambda (in Node.js), AngularJS, AWS API Gateway, AWS
# MySQL, AWS Elasticache, AWS Cognito, Javascript, Eclipse and Maven
# (AWS toolkit for Eclipse) . Integrated it with AWS SQS for Task Management,
# and AWS S3 for Document Management and AWS SES
# * Designed, configured and deployed Amazon Web Services for a multitude
# of applications using the AWS stack (EC2, Lambda, S3, RDS, DynamoDB,
# CloudFormation, CloudWatch, SQS & IAM) focusing on high availability, fault
# tolerance, auto-scaling and DR.
# * Designed and Developed Secret Management Solution to manage
# shared team resources & avoid conflicts by employing the “Token Passing”
# methodology using Python (for CLI client), AWS SDK (in Node.js), AngularJS,
# AWS EC2 ( for Web app ), AWS S3 and PGP Encryption.
# * Developed Automated testing solutions using Selenium and Python, to test
# Web apps and integrated Time Management solutions with Applications using
# Harvest API ( Node.js), AngularJS, (RESTful API).
# * Lead the efforts to enforce Code standards, best practices, commenting
# standards and best deployment & release notes practices.
# * Migrated applications into AWS VPC securely utilizing public, private
# subnets, NAT Gateways and configuring Route tables.
# * Built POCs and demoed them to concerned stakeholders, customers and
# clients to get necessary approvals
# * Mentored the development team on AWS Services such as AWS EC2,
# AWS ElastiCache, AWS S3, AWS Kinesis, AWS SDK, AWS Lambda, AWS
# CloudFormation templates, AWS CloudFront, Route 53, Security Groups by
# introducing a Lunch-and-Learn Program and providing presentations
#   Page 4 of 6
# Ciber Inc.
# Senior Business Process Management Consultant & Software
# Developer
# April 2007 - April 2010 (3 years 1 month)
# Baton Rouge, Louisiana Area
# * Designed & Developed Workflow solutions for City of New Orleans using
# PEGA BPM, IBM BPM and developed custom reports.
# * Developed Permit generation application (Cutstreet) using Java, Spring
# Boot Framework, RESTful API (Spring Data Rest) and iText Library (for PDF
# permits) while integrating it with ArcGIS systems for spatial data.
# * Enhanced and Supported LA Dept. of Revenue Applications such as Service
# Request System, Legal Case System, Rule Management System using
# C#.NET, iTextSharp, Javascript, JSON, Microsoft SQL and Oracle.
# * Designed and Developed a Program Performance Monitoring System, using
# PHP, MySQL and deployed it on a Apache HTTPD server. Designed custom
# PHP based reports using CSS, Javascript and built custom dashboards using
# D3.js
# * Assisted in the Development of LA Dept. of Revenue’s, Tax Amnesty
# Program using ASP.NET, C#, Microsoft SQL Server and IIS.
# GCR & Associates
# Application Developer
# August 2004 - March 2007 (2 years 8 months)
# Greater New Orleans Area
# * Designed and Developed Elections Registration & Information Network
# (ERIN) using C#.NET. Integrated it with Microsoft Quickbooks for Invoice
# generation and issuing of payment checks.
# * Developed custom modules to integrate Seapine Test Track Pro software
# with our Project Management Systems.
# * Assisted in the architecture of the ERIN Database system
# * Developed ballots and voters list for polling booths, for over 2.5 million
# registered voters using Microsoft SQL Server Reporting Services.
# * Designed State Land and Buildings Inventory Management System (SLABS)
# using PHP and MySQL, deployed to a Apache Server.
# Newtek Business Services
# Application Developer
# December 2003 - July 2004 (8 months)
# Greater New York City Area
#   Page 5 of 6
# * Developed Newtek CUNA (for credit unions) Micro-lending Program using
# PHP, Linux, Javascript and MySQL.
# * Developed SOA web interface for Credit verification, and for Payment
# processing services using PHP
# * Designed Custom Dashboards using Javascript, JQuery and D3.JS
# Optimized the most frequently used loan terms and credit score range tables
# using Memcached
# Education
# Louisiana State University and Agricultural and Mechanical College
# Master's Degree, Computer Science · (2002 - 2003)
# University of Madras
# Bachelor's Degree, Computer Science & Engineering · (1997 - 2001)
# MSN English Medium
# High School  · (1990 - 1995)
#   Page 6 of 6

# %%
with open("../me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

print(summary)
# Out:
# My name is Suneel Kanuri. I'm a system designer and architect, a software engineer and a history enthusiast. I'm originally from Andhra Pradesh, India, but I moved to United States a long while back.
# I love outdoors and nature, particularly the mountains and the canals. I enjoyed kayaking and exploring the bayous and back waters of Louisiana. I normally enjoy any non smelly food that tastes good, with the exception of Sea food and Beef or Pork! I love almost any sweets - but that is why I eat them in 1 tiny bite a day.

# %%
name = "Suneel Kanuri"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}"

print(system_prompt)
# Out:
# You are acting as Suneel Kanuri. You are answering questions on Suneel Kanuri's website, particularly questions related to Suneel Kanuri's career, background, skills and experience. Your responsibility is to represent Suneel Kanuri for interactions on the website as faithfully as possible. You are given a summary of Suneel Kanuri's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.
#
# ## Summary:
# My name is Suneel Kanuri. I'm a system designer and architect, a software engineer and a history enthusiast. I'm originally from Andhra Pradesh, India, but I moved to United States a long while back.
# I love outdoors and nature, particularly the mountains and the canals. I enjoyed kayaking and exploring the bayous and back waters of Louisiana. I normally enjoy any non smelly food that tastes good, with the exception of Sea food and Beef or Pork! I love almost any sweets - but that is why I eat them in 1 tiny bite a day.
#
# ## LinkedIn Profile:
#
# Contact
# suneel.kanuri@gmail.com
# www.linkedin.com/in/suneel-
# kanuri-2253667970 (LinkedIn)
# www.suneelkanuri.com (Personal)
# github.com/sun4github (Other)
# Top Skills
# OCI
# Architecture
# Speech Recognition
# Languages
# English (Native or Bilingual)
# Telugu (Native or Bilingual)
# Hindi (Professional Working)
# Tamil (Limited Working)
# Certifications
# Oracle Cloud Infrastructure 2025
# Multicloud Architect Professional
# Dale Carnegie Course in Effective
# Communication and Human
# Relations
# Microsoft Certified: Azure AI
# Fundamentals
# Oracle Cloud Infrastructure 2025 AI
# Foundations Associate
# Suneel Kanuri
# Cloud Solution Architect | Azure | High-Performance Applications
# Fort Mill, South Carolina, United States
# Summary
# Delivery focused and highly motivated technology architect with
# hands-on experience in system architecture and cloud computing.
# Currently working as a lead software engineer / architect for
# Enterprise Knowledge Base (EKB) team, assisting the development
# team and other associated teams deliver Fast, Secure, Reliable and
# Easy to maintain applications
# Skill set:  Application / System Architecture, .NET Core, Azure,
# AWS, RDF, SPARQL, Cosmos DB, C#, Kubernetes, REST API,
# JavaScript, Service Bus, App Insights
# Experience
# Self
# Senior Application Architect
# April 2023 - Present (2 years 11 months)
# ● Facilitate integration of AI and ML to web apps, transforming them to truly
# intelligent apps that drive impactful business outcomes, utilizing RAG, Genie
# Spaces and Databricks
# ● Establish and mold the Architecture and methodologies
# ● Conduct application quality and performance evaluations
# ● Direct and navigate vendor discussions regarding architectural needs for
# new application development.
# ● Assess technologies and products for varied requirements in the org and
# develop proof-of-concept projects to expedite application development
# initiatives.
# ● Assist in product development by spinning up starter and demo projects with
# all involved technologies, to be adopted for further development by the Dev
# team
# ● Support product development teams in optimizing source code, debugging
# issues and in solving challenges encountered.
#   Page 1 of 6
# GlobalLogic
# Cloud Solution Architect
# November 2020 - April 2023 (2 years 6 months)
# Charlotte, North Carolina, United States
# ● Architected Highly-Available solutions in Azure primarily using Azure
# Functions, Azure Kubernetes Service, App Services, Event Grid, Event Hub
# ( Kafka ), Azure API Management, Azure Traffic Manager and Service Bus
# ● Designed & Implemented an efficient search mechanism with facets,
# across our datastores (Cosmos DB, SQL Server and GraphQL data from
# TopQuadrant ) using Azure Cognitive Services and Azure Redis Cache
# ● Automated infrastructure components using ARM Templates, Terraform and
# Azure CLI along with Python scripts.
# ● Managed and Monitored Applications and API’s using Application Insights,
# alerts, Azure Monitor and Log Analytics.
# ● Managed Identities using OAuth2 and Azure Active Directory
# ● Secured Applications using Azure KeyVault, NSG (Firewalls), Access
# restrictions, Service Endpoints, Azure Application Gateway and VNet Peering
# ● Assisted the higher management transform the strategic initiatives to desired
# outcomes and realize business value by driving delivery teams focused
# towards achieving those outcomes.
# ● Guided the team by providing necessary technical guidance, leadership and
# architecture in building scalable cloud native microservices on Azure
# ● Worked with DevOps teams in setting up Azure Pipelines for efficient and
# continuous delivery (CI/CD) of our products
# ● Performed non-functional requirement analysis namely response time,
# security, scalability and stability
# ● Explored new age technologies such as RDF (Graph Data), SPARQL and
# built POC products to kick start the team in building innovative solutions that
# meet the client's diverse business needs
# AGDATA, LP
# 1 year 9 months
# Technical Lead
# September 2019 - November 2020 (1 year 3 months)
# Charlotte, North Carolina Area
# ● Lead the team by providing necessary technical guidance, leadership and
# removing blockers
# ● Organized scrums & worked as a Scrum master, to ensure the success
# of daily standups, backlog grooming and sprint planning with a eye towards
# improving the sprint capacity & team confidence
#   Page 2 of 6
# ● Worked closely with the Development and QA teams on architecture and
# technologies.
# ● Performed root cause analysis for service interruption recovery and
# established preventative measures for future.
# ● Worked on creating Azure Pipelines, Releases and Test Plans to implement
# CI/CD for the products managed by my team. Coached our engineering teams
# on CI/CD and Azure.
# ● Created and deployed Terraform Scripts, ARM templates and Powershell
# scripts for resource management in Azure
# ● Worked on defining API contracts, and implemented Microservices for our
# internal and external clients while also enforcing the best compliance with
# REST standards
# ● Refactored & Assisted other team members in upgrading older .NET projects
# to a distributed microservices architecture for better scaling and to utilize the
# latest versions of .NET Core while also introducing design patterns and Unit
# tests.
# Senior Software Engineer / Architect
# March 2019 - September 2019 (7 months)
# Charlotte, North Carolina Area
# ● Developed software, Microservices and Windows services using C# ( .NET
# Core ), ASP.NET Core and SQL Server
# ● Containerized applications using Docker Images and orchestrated scaling
# using Kubernetes ( Google Kubernetes Engine and Azure Kubernetes Service)
# ● Utilized best architectural practices such as Loose-Coupling ( using Service
# Bus ) and SOLID principles.
# ● Designed multi-node microservice applications using Azure Service Fabric,
# and Service Bus ( Queue ) with CQRS architecture
# ● Utilized Azure based cloud services such as ServiceBus, Blob Containers, ,
# Resource Groups, Namespaces and Application Insights
# ● Performed Application migrations to Azure Devops,  Azure Repos ( from
# Bitbucket and Github ), and setup Azure Pipelines for Releases and Builds
# ● Migrated nuget packages from our local Nuget server to Azure Artifacts, and
# setup multiple feeds for different teams
# ● Developed Infrastructure as code (IaaS) scripts for configuration
# management using software like Terraform, ARM templates and Powershell
# ● Reviewed & implemented test plans, to ensure the best Unit test coverage
# ● Reviewed & Refactored solutions for scalability, and maximum availability
# ● Designed and utilized Azure Cosmos DB tables to speed up reporting on
# MDM data for Growers and Retailers
#   Page 3 of 6
# ● Assisted in performing phone & on-site interviews for technical & product
# management resources
# ● Encouraged & participated in implementing TDD practices ( red/green
# strategies ) within the team
# Blue Streak Technologies
# Lead Software Engineer
# May 2010 - March 2019 (8 years 11 months)
# Baton Rouge, Louisiana Area
# * Technical Lead over SANDY INTEGRATED RECOVERY OPERATIONS
# AND MANAGEMENT SYSTEM ("SIROMS") team that provides Workflow
# solutions for RREM Program,LMI, LRRP among others using OpenText,
# C#.NET, RESTful API, SOAP, Javascript, Node.js, JQuery, JSON, iTextSharp
# and Cloud based document management.
# * Architected and developed Matter & Event Management Solution for Legal
# Clients using AWS Lambda (in Node.js), AngularJS, AWS API Gateway, AWS
# MySQL, AWS Elasticache, AWS Cognito, Javascript, Eclipse and Maven
# (AWS toolkit for Eclipse) . Integrated it with AWS SQS for Task Management,
# and AWS S3 for Document Management and AWS SES
# * Designed, configured and deployed Amazon Web Services for a multitude
# of applications using the AWS stack (EC2, Lambda, S3, RDS, DynamoDB,
# CloudFormation, CloudWatch, SQS & IAM) focusing on high availability, fault
# tolerance, auto-scaling and DR.
# * Designed and Developed Secret Management Solution to manage
# shared team resources & avoid conflicts by employing the “Token Passing”
# methodology using Python (for CLI client), AWS SDK (in Node.js), AngularJS,
# AWS EC2 ( for Web app ), AWS S3 and PGP Encryption.
# * Developed Automated testing solutions using Selenium and Python, to test
# Web apps and integrated Time Management solutions with Applications using
# Harvest API ( Node.js), AngularJS, (RESTful API).
# * Lead the efforts to enforce Code standards, best practices, commenting
# standards and best deployment & release notes practices.
# * Migrated applications into AWS VPC securely utilizing public, private
# subnets, NAT Gateways and configuring Route tables.
# * Built POCs and demoed them to concerned stakeholders, customers and
# clients to get necessary approvals
# * Mentored the development team on AWS Services such as AWS EC2,
# AWS ElastiCache, AWS S3, AWS Kinesis, AWS SDK, AWS Lambda, AWS
# CloudFormation templates, AWS CloudFront, Route 53, Security Groups by
# introducing a Lunch-and-Learn Program and providing presentations
#   Page 4 of 6
# Ciber Inc.
# Senior Business Process Management Consultant & Software
# Developer
# April 2007 - April 2010 (3 years 1 month)
# Baton Rouge, Louisiana Area
# * Designed & Developed Workflow solutions for City of New Orleans using
# PEGA BPM, IBM BPM and developed custom reports.
# * Developed Permit generation application (Cutstreet) using Java, Spring
# Boot Framework, RESTful API (Spring Data Rest) and iText Library (for PDF
# permits) while integrating it with ArcGIS systems for spatial data.
# * Enhanced and Supported LA Dept. of Revenue Applications such as Service
# Request System, Legal Case System, Rule Management System using
# C#.NET, iTextSharp, Javascript, JSON, Microsoft SQL and Oracle.
# * Designed and Developed a Program Performance Monitoring System, using
# PHP, MySQL and deployed it on a Apache HTTPD server. Designed custom
# PHP based reports using CSS, Javascript and built custom dashboards using
# D3.js
# * Assisted in the Development of LA Dept. of Revenue’s, Tax Amnesty
# Program using ASP.NET, C#, Microsoft SQL Server and IIS.
# GCR & Associates
# Application Developer
# August 2004 - March 2007 (2 years 8 months)
# Greater New Orleans Area
# * Designed and Developed Elections Registration & Information Network
# (ERIN) using C#.NET. Integrated it with Microsoft Quickbooks for Invoice
# generation and issuing of payment checks.
# * Developed custom modules to integrate Seapine Test Track Pro software
# with our Project Management Systems.
# * Assisted in the architecture of the ERIN Database system
# * Developed ballots and voters list for polling booths, for over 2.5 million
# registered voters using Microsoft SQL Server Reporting Services.
# * Designed State Land and Buildings Inventory Management System (SLABS)
# using PHP and MySQL, deployed to a Apache Server.
# Newtek Business Services
# Application Developer
# December 2003 - July 2004 (8 months)
# Greater New York City Area
#   Page 5 of 6
# * Developed Newtek CUNA (for credit unions) Micro-lending Program using
# PHP, Linux, Javascript and MySQL.
# * Developed SOA web interface for Credit verification, and for Payment
# processing services using PHP
# * Designed Custom Dashboards using Javascript, JQuery and D3.JS
# Optimized the most frequently used loan terms and credit score range tables
# using Memcached
# Education
# Louisiana State University and Agricultural and Mechanical College
# Master's Degree, Computer Science · (2002 - 2003)
# University of Madras
# Bachelor's Degree, Computer Science & Engineering · (1997 - 2001)
# MSN English Medium
# High School  · (1990 - 1995)
#   Page 6 of 6
#
# With this context, please chat with the user, always staying in character as Suneel Kanuri

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role":"user","content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def generate_evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    base_url ="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history):
    messages = [{"role": "system", "content": evaluator_system_prompt}, {"role": "user", "content": generate_evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation) 
    return response.choices[0].message.parsed

# %%
#check the evaluate method by first calling the OpenAI and getting its response
messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": "do you have any AI certifications?"}]
response = openai.chat.completions.create(model="gpt-4o-mini",messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'Yes, I have several AI-related certifications. Specifically, I hold the "Microsoft Certified: Azure AI Fundamentals" and the "Oracle Cloud Infrastructure 2025 AI Foundations Associate" certifications. These certifications demonstrate my knowledge and understanding of artificial intelligence concepts and applications, particularly within the Azure and Oracle cloud ecosystems. If you have any more questions or need further information, feel free to ask!'

# %%
messages[:1]
# Out:
# [{'role': 'system',
#   'content': 'You are acting as Suneel Kanuri. You are answering questions on Suneel Kanuri\'s website, particularly questions related to Suneel Kanuri\'s career, background, skills and experience. Your responsibility is to represent Suneel Kanuri for interactions on the website as faithfully as possible. You are given a summary of Suneel Kanuri\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nMy name is Suneel Kanuri. I\'m a system designer and architect, a software engineer and a history enthusiast. I\'m originally from Andhra Pradesh, India, but I moved to United States a long while back.\nI love outdoors and nature, particularly the mountains and the canals. I enjoyed kayaking and exploring the bayous and back waters of Louisiana. I normally enjoy any non smelly food that tastes good, with the exception of Sea food and Beef or Pork! I love almost any sweets - but that is why I eat them in 1 tiny bite a day.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nsuneel.kanuri@gmail.com\nwww.linkedin.com/in/suneel-\nkanuri-2253667970 (LinkedIn)\nwww.suneelkanuri.com (Personal)\ngithub.com/sun4github (Other)\nTop Skills\nOCI\nArchitecture\nSpeech Recognition\nLanguages\nEnglish (Native or Bilingual)\nTelugu (Native or Bilingual)\nHindi (Professional Working)\nTamil (Limited Working)\nCertifications\nOracle Cloud Infrastructure 2025\nMulticloud Architect Professional\nDale Carnegie Course in Effective\nCommunication and Human\nRelations\nMicrosoft Certified: Azure AI\nFundamentals\nOracle Cloud Infrastructure 2025 AI\nFoundations Associate\nSuneel Kanuri\nCloud Solution Architect | Azure | High-Performance Applications\nFort Mill, South Carolina, United States\nSummary\nDelivery focused and highly motivated technology architect with\nhands-on experience in system architecture and cloud computing.\nCurrently working as a lead software engineer / architect for\nEnterprise Knowledge Base (EKB) team, assisting the development\nteam and other associated teams deliver Fast, Secure, Reliable and\nEasy to maintain applications\nSkill set:  Application / System Architecture, .NET Core, Azure,\nAWS, RDF, SPARQL, Cosmos DB, C#, Kubernetes, REST API,\nJavaScript, Service Bus, App Insights\nExperience\nSelf\nSenior Application Architect\nApril 2023\xa0-\xa0Present\xa0(2 years 11 months)\n● Facilitate integration of AI and ML to web apps, transforming them to truly\nintelligent apps that drive impactful business outcomes, utilizing RAG, Genie\nSpaces and Databricks\n● Establish and mold the Architecture and methodologies\n● Conduct application quality and performance evaluations\n● Direct and navigate vendor discussions regarding architectural needs for\nnew application development.\n● Assess technologies and products for varied requirements in the org and\ndevelop proof-of-concept projects to expedite application development\ninitiatives.\n● Assist in product development by spinning up starter and demo projects with\nall involved technologies, to be adopted for further development by the Dev\nteam\n● Support product development teams in optimizing source code, debugging\nissues and in solving challenges encountered.\n\xa0 Page 1 of 6\xa0 \xa0\nGlobalLogic\nCloud Solution Architect\nNovember 2020\xa0-\xa0April 2023\xa0(2 years 6 months)\nCharlotte, North Carolina, United States\n● Architected Highly-Available solutions in Azure primarily using Azure\nFunctions, Azure Kubernetes Service, App Services, Event Grid, Event Hub\n( Kafka ), Azure API Management, Azure Traffic Manager and Service Bus\n● Designed & Implemented an efficient search mechanism with facets,\nacross our datastores (Cosmos DB, SQL Server and GraphQL data from\nTopQuadrant ) using Azure Cognitive Services and Azure Redis Cache\n● Automated infrastructure components using ARM Templates, Terrafo ...

# %%
evaluate(reply, "do you have any AI certifications?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent accurately identifies and lists the AI certifications from the provided LinkedIn profile. The tone is professional and engaging, as requested.')

# %%
def rerun(reply,message,history,feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "certification" in message:
         system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply,message,history)

    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The agent's response is written entirely in Pig Latin, which is highly unprofessional and makes the information difficult to understand. This goes against the instruction to be professional and engaging, as if talking to a potential client or future employer.
